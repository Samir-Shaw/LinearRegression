# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../data/raw/used_car_price_dataset.csv")
df.head()
# Out:
#    car_age  km_driven  engine_cc  mileage_kmpl  max_power_bhp  torque_nm  \
# 0      NaN        NaN      807.0          12.3          107.7      159.0
# 1     11.0   130714.0     1890.0          21.0          182.3      281.3
# 2     13.0   180944.0     4445.0           NaN          476.6      700.0
# 3      5.0    91462.0      869.0           8.8           53.9      106.5
# 4      8.0   136421.0     2239.0          26.9          209.0      467.3
#
#    seats  owner_count     brand fuel_type transmission       seller_type  \
# 0    8.0          3.0   Hyundai    Petrol    Automatic  Trustmark Dealer
# 1    8.0          4.0      Tata    Diesel    Automatic  Trustmark Dealer
# 2    7.0          4.0      Audi       CNG       Manual  Trustmark Dealer
# 3    2.0          3.0  Mercedes       CNG    Automatic        Individual
# 4    8.0          4.0  Mercedes    Hybrid    Automatic        Individual
#
#   location  condition  selling_price
# 0  Kolkata       Poor         238967
# 1     Pune  Excellent        1292259
# 2  Kolkata       Fair        2609331
# 3  Kolkata       Good        1978831
# 4      NaN       Good        2389074

# %%
df.shape
# Out:
# (5075, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   car_age        4741 non-null   float64
#  1   km_driven      4761 non-null   float64
#  2   engine_cc      4813 non-null   float64
#  3   mileage_kmpl   4769 non-null   float64
#  4   max_power_bhp  4764 non-null   float64
#  5   torque_nm      4772 non-null   float64
#  6   seats          4757 non-null   float64
#  7   owner_count    4777 non-null   float64
#  8   brand          4769 non-null   str
#  9   fuel_type      4807 non-null   str
#  10  transmission   4768 non-null   str
#  11  seller_type    4781 non-null   str
#  12  location       4749 non-null   str
#  13  condition      4755 non-null   str
#  14  selling_price  5075 non-null   int64
# dtypes: float64(8), int64(1), str(6)
# memory usage: 594.9 KB

# %%
df.describe()
# Out:
#            car_age      km_driven    engine_cc  mileage_kmpl  max_power_bhp  \
# count  4741.000000    4761.000000  4813.000000   4769.000000    4764.000000
# mean      7.969205  115732.145348  2016.862040     19.032040     201.868682
# std       4.279268   59187.728125  1157.358543      6.406626     119.595153
# min       1.000000    5000.000000   700.000000      8.000000      40.000000
# 25%       4.000000   70094.000000  1118.000000     13.400000     112.975000
# 50%       8.000000  115825.000000  1712.000000     19.200000     168.000000
# 75%      12.000000  161471.000000  2902.000000     24.600000     261.600000
# max      15.000000  288915.000000  4599.000000     30.000000     500.000000
#
#          torque_nm        seats  owner_count  selling_price
# count  4772.000000  4757.000000  4777.000000   5.075000e+03
# mean    376.238139     5.380702     1.996441   1.500229e+06
# std     193.675829     1.959297     1.407159   6.939104e+05
# min      50.000000     2.000000     0.000000   5.000000e+04
# 25%     219.575000     4.000000     1.000000   9.847800e+05
# 50%     337.850000     6.000000     2.000000   1.380846e+06
# 75%     526.350000     7.000000     3.000000   1.986262e+06
# max     700.000000     8.000000     4.000000   4.341459e+06

# %%
df.isnull().sum()
# Out:
# car_age          334
# km_driven        314
# engine_cc        262
# mileage_kmpl     306
# max_power_bhp    311
# torque_nm        303
# seats            318
# owner_count      298
# brand            306
# fuel_type        268
# transmission     307
# seller_type      294
# location         326
# condition        320
# selling_price      0
# dtype: int64

# %%
df.dtypes
# Out:
# car_age          float64
# km_driven        float64
# engine_cc        float64
# mileage_kmpl     float64
# max_power_bhp    float64
# torque_nm        float64
# seats            float64
# owner_count      float64
# brand                str
# fuel_type            str
# transmission         str
# seller_type          str
# location             str
# condition            str
# selling_price      int64
# dtype: object

# %%
df.nunique()
# Out:
# car_age            15
# km_driven        4527
# engine_cc        1515
# mileage_kmpl      221
# max_power_bhp    2528
# torque_nm        2838
# seats               6
# owner_count         5
# brand              15
# fuel_type           5
# transmission        2
# seller_type         3
# location           10
# condition           4
# selling_price    4986
# dtype: int64

# %%
for col in ['brand', 'fuel_type', 'transmission', 'seller_type', 'location', 'condition']:
    print(f"\n--- {col} ---")
    print(df[col].value_counts(dropna=False))
# Out:
# --- brand ---
# brand
# Mercedes      350
# Renault       350
# BMW           336
# Ford          335
# Kia           334
# Audi          331
# Mahindra      327
# Toyota        319
# Skoda         316
# Hyundai       315
# Nissan        310
# NaN           306
# Maruti        301
# Tata          295
# Honda         283
# Volkswagen    267
# Name: count, dtype: int64
#
# --- fuel_type ---
# fuel_type
# Diesel      1012
# Hybrid       957
# Petrol       951
# CNG          945
# Electric     942
# NaN          268
# Name: count, dtype: int64
#
# --- transmission ---
# transmission
# Automatic    2395
# Manual       2373
# NaN           307
# Name: count, dtype: int64
#
# --- seller_type ---
# seller_type
# Trustmark Dealer    1620
# Individual          1613
# Dealer              1548
# NaN                  294
# Name: count, dtype: int64
#
# --- location ---
# location
# Mumbai       501
# Bangalore    499
# Chennai      497
# Lucknow      488
# Jaipur       486
# Pune         479
# Ahmedabad    469
# Hyderabad    460
# Delhi        453
# Kolkata      417
# NaN          326
# Name: count, dtype: int64
#
# --- condition ---
# condition
# Excellent    1219
# Fair         1203
# Poor         1174
# Good         1159
# NaN           320
# Name: count, dtype: int64

# %%
df.hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))

df[['engine_cc', 'max_power_bhp']].boxplot()

plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6, 6))

df[['selling_price']].boxplot()

plt.show()

# %%
plt.figure(figsize=(6, 6))

df[['km_driven']].boxplot()

plt.show()
